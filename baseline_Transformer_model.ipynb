# %% [markdown]
# # 6) Spatio-Temporal Transformer (Multi-Head)

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt


mpl.rcParams.update({
    "font.family": "serif",
    "font.serif": ["Times New Roman", "Times", "DejaVu Serif"],
    "font.size": 16,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "xtick.labelsize": 16,
    "ytick.labelsize": 16,
    "legend.fontsize": 16,
    "figure.dpi": 350,
    "savefig.dpi": 350,
    "savefig.bbox": "tight",
    "axes.grid": True,
    "grid.alpha": 0.25,
    "lines.linewidth": 1.6,
    "axes.spines.top": False,
    "axes.spines.right": False,
})

np.random.seed(42)
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 200)


def add_value_labels(ax, fmt="{:.3g}", vpad=0.01):
    """Подписи над столбцами bar-chart."""
    ymin, ymax = ax.get_ylim()
    vrange = ymax - ymin if ymax > ymin else 1.0
    for rect in ax.patches:
        h = rect.get_height()
        if np.isfinite(h):
            x = rect.get_x() + rect.get_width() / 2.0
            y = h + vpad * vrange
            ax.text(x, y, fmt.format(h), ha="center", va="bottom")

def show_hist(series: pd.Series, title: str, xlabel: str, bins: int = 60,
              figsize=(9, 6), dpi=350):
    """Гистограмма без сохранения — только show()."""
    s = pd.to_numeric(series, errors="coerce").dropna()
    if s.empty:
        return
    fig = plt.figure(figsize=figsize, dpi=dpi)
    plt.hist(s, bins=bins)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel("Count")
    plt.tight_layout()
    plt.show()

def heatmap_with_ann(mat: np.ndarray, xlabels, ylabels, title: str,
                     figsize=(10, 8), dpi=350, fmt="{:.2f}"):
    """Матрица с подписями значений внутри ячеек."""
    fig = plt.figure(figsize=figsize, dpi=dpi)
    ax = plt.gca()
    im = ax.imshow(mat, aspect="auto")
    plt.colorbar(im)
    ax.set_xticks(range(len(xlabels)))
    ax.set_xticklabels(list(xlabels), rotation=45, ha="right")
    ax.set_yticks(range(len(ylabels)))
    ax.set_yticklabels(list(ylabels))
    ax.set_title(title)
    ax.grid(False)

    
    nrows, ncols = mat.shape
    norm = plt.Normalize(vmin=np.nanmin(mat), vmax=np.nanmax(mat))
    cmap = im.get_cmap()
    for i in range(nrows):
        for j in range(ncols):
            v = mat[i, j]
            if np.isfinite(v):
                rgba = cmap(norm(v))
                luminance = 0.299*rgba[0] + 0.587*rgba[1] + 0.114*rgba[2]
                ax.text(j, i, fmt.format(v),
                        ha="center", va="center",
                        color=("black" if luminance > 0.5 else "white"))
    plt.tight_layout()
    plt.show()

# %%
CANDIDATES = [
    "original_dataset_china/renewables_combined_FULL.csv",
    "original_dataset_china/renewables_combined_CLEAN.csv",
]
DATA_PATH = None
for p in CANDIDATES:
    try:
        _df = pd.read_csv(p, low_memory=False)
        DATA_PATH = p
        break
    except Exception:
        continue


df = _df.copy()
print("Loaded:", DATA_PATH)
print("Shape:", df.shape)
print("Columns:", list(df.columns)[:20], "...")


df["timestamp"] = pd.to_datetime(df.get("timestamp"), errors="coerce")
df["year"] = df["timestamp"].dt.year
df["month"] = df["timestamp"].dt.month
df["day"] = df["timestamp"].dt.day
df["hour"] = df["timestamp"].dt.hour
df["doy"] = df["timestamp"].dt.dayofyear
df["week"] = df["timestamp"].dt.isocalendar().week.astype("Int64")


if "season_derived" not in df.columns:

    def _season(m: int) -> str:
        if m in (12, 1, 2):
            return "winter"
        if m in (3, 4, 5):
            return "spring"
        if m in (6, 7, 8):
            return "summer"
        return "autumn"

    df["season_derived"] = df["month"].map(_season)

print("Time range:", df["timestamp"].min(), "→", df["timestamp"].max())
# Out:
# Loaded: original_dataset_china/renewables_combined_FULL.csv
# Shape: (8753, 18)
# Columns: ['datetime_solar', 'hour_index_solar', 'temperature_solar', 'humidity_solar', 'surface_irradiance_solar', 'toa_irradiance_solar', 'kWh_solar_power_solar', 'sheet_solar', 'timestamp', 'specific_humidity_solar', 'relative_humidity_solar', 'datetime_wind', 'hour_index_wind', 'air_density_wind', 'wind_speed_wind', 'kWh_wind_power_wind', 'sheet_wind', 'season_derived'] ...
# Time range: 2019-01-01 08:00:00 → 2019-12-31 23:00:00

# %%
cols = df.columns.tolist()

def find_power_target(suffix: str):
    
    cands = [c for c in cols if c.endswith(suffix) and c.lower().startswith("kwt_")]
    if cands:
        return cands[0]
    
    cands = [c for c in cols if c.endswith(suffix) and ("power" in c.lower())]
    return cands[0] if cands else None

solar_target = find_power_target("_solar")
wind_target  = find_power_target("_wind")


solar_feature_keys = ["irradiance_solar", "surface_irradiance_solar", "toa_irradiance_solar",
                      "temperature_solar", "module_temperature_solar", "humidity_solar",
                      "relative_humidity_solar", "specific_humidity_solar"]
wind_feature_keys  = ["wind_speed_wind", "wind_direction_wind", "air_density_wind"]

solar_feats = [c for c in cols if any(k == c for k in solar_feature_keys)]
wind_feats  = [c for c in cols if any(k == c for k in wind_feature_keys)]

print("Solar target:", solar_target)
print("Wind  target:", wind_target)
print("Solar features:", solar_feats)
print("Wind  features:", wind_feats)
# Out:
# Solar target: kWh_solar_power_solar
# Wind  target: kWh_wind_power_wind
# Solar features: ['temperature_solar', 'humidity_solar', 'surface_irradiance_solar', 'toa_irradiance_solar', 'specific_humidity_solar', 'relative_humidity_solar']
# Wind  features: ['air_density_wind', 'wind_speed_wind']

# %%
print("Rows, Cols:", df.shape)
print("Time coverage:", df["timestamp"].min(), "→", df["timestamp"].max())
print("Season distribution:", df["season_derived"].value_counts(dropna=False).to_dict())


if "timestamp" in df.columns:
    dup_count = int(df["timestamp"].duplicated().sum())
    print("Duplicate timestamp rows:", dup_count)


missing = (
    df.isna().sum().sort_values(ascending=False)
      .to_frame("missing_count")
      .assign(missing_pct=lambda s: (s["missing_count"] / df.shape[0] * 100).round(3))
)
print(missing.head(20))


desc = df.select_dtypes(include=[np.number]).describe().T
print(desc.head(20))


print(df.head(5))
# Out:
# Rows, Cols: (8753, 24)
# Time coverage: 2019-01-01 08:00:00 → 2019-12-31 23:00:00
# Season distribution: {'spring': 2209, 'summer': 2208, 'autumn': 2184, 'winter': 2152}
# Duplicate timestamp rows: 1
#                          missing_count  missing_pct
# datetime_solar                       0          0.0
# hour_index_solar                     0          0.0
# doy                                  0          0.0
# hour                                 0          0.0
# day                                  0          0.0
# month                                0          0.0
# year                                 0          0.0
# season_derived                       0          0.0
# sheet_wind                           0          0.0
# kWh_wind_power_wind                  0          0.0
# wind_speed_wind                      0          0.0
# air_density_wind                     0          0.0
# hour_index_wind                      0          0.0
# datetime_wind                        0          0.0
# relative_humidity_solar              0          0.0
# specific_humidity_solar              0          0.0
# timestamp                            0          0.0
# sheet_solar                          0          0.0
# kWh_solar_power_solar                0          0.0
# toa_irradiance_solar                 0          0.0
#                            count         mean          std     min     25%  \
# hour_index_solar          8753.0  1094.747972   631.941407     1.0   548.0
# temperature_solar         8753.0     1.879691     14.58504 -33.461 -10.755
# humidity_solar            8753.0     0.005186     0.004515     0.0   0.001
# surface_irradiance_solar  8753.0   160.872361   220.102427     0.0     0.0
# toa_irradiance_solar      8753.0   294.954069    375.57412     0.0     0.0
# kWh_solar_power_solar     8753.0   949.602034  1333.233318     0.0     0.0
# specific_humidity_solar   8753.0     0.005186     0.004515     0.0   0.001
# relative_humidity_solar   8753.0     0.518645     0.451541     0.0     0.1
# hour_index_wind           8753.0  1094.747858   631.941205     1.0   548.0
# air_density_wind          8753.0     1.232142     0.075589   1.108   1.163
# wind_speed_wind           8753.0     6.122538      2.51422    0.24   4.385
# kWh_wind_power_wind       8753.0  1412.407743  1205.110733     0.0  412.22
# year                      8753.0       2019.0          0.0  2019.0  2019.0
# month                     8753.0     6.530904     3.445413     1.0     4.0
# day                       8753.0    15.735748     8.790509     1.0     8.0
# hour                      8753.0    11.508626     6.921864     0.0     6.0
# doy                       8753.0   183.162687   105.270892     1.0    92.0
# week                      8753.0    26.452873    15.034196     1.0    13.0
#
#                                50%       75%       max
# hour_index_solar            1095.0    1642.0    2209.0
# temperature_solar            2.805     14.79    29.317
# humidity_solar               0.003     0.009     0.019
# surface_irradiance_solar    11.342   299.109    898.76
# toa_irradiance_solar         36.73   563.748  1196.745
# kWh_solar_power_solar       18.744  1789.113    4500.0
# specific_humidity_solar      0.003     0.009     0.019
# relative_humidity_solar        0.3       0.9       1.9
# hour_index_wind             1095.0    1642.0    2208.0
# air_density_wind             1.223     1.296     1.402
# wind_speed_wind              6.029     7.674    18.325
# kWh_wind_power_wind       1124.664  2159.435  4956.556
# year                        2019.0    2019.0    2019.0
# month                          7.0      10.0      12.0
# day                           16.0      23.0      31.0
# hour                          12.0      18.0      23.0
# doy                          183.0     274.0     365.0
# week                          26.0      39.0      52.0
#         datetime_solar  hour_index_solar  temperature_solar  humidity_solar  \
# 0  2019-01-01 08:00:00               745            -19.889           0.001
# 1  2019-01-01 09:00:00               746            -19.004           0.001
# 2  2019-01-01 10:00:00               747            -17.971           0.001
# 3  2019-01-01 11:00:00               748            -17.281           0.001
# 4  2019-01-01 12:00:00               749            -16.738           0.001
#
#    surface_irradiance_solar  toa_irradiance_solar  kWh_solar_power_solar  \
# 0                    82.680               209.252                257.690
# 1                   149.553               345.604                530.391
# 2                   193.625               430.654                871.016
# 3                   203.808               458.550               1087.304
# 4                   185.193               427.391               1010.161
#
#   sheet_solar           timestamp  specific_humidity_solar  \
# 0      Sheet1 2019-01-01 08:00:00                    0.001
# 1      Sheet1 2019-01-01 09:00:00                    0.001
# 2      Sheet1 2019-01-01 10:00:00                    0.001
# 3      Sheet1 2019-01-01 11:00:00                    0.001
# 4      Sheet1 2019-01-01 12:00:00                    0.001
#
#    relative_humidity_solar        datetime_wind  hour_index_wind  \
# 0                      0.1  2019-01-01 08:00:00              745
# 1                      0.1  2019-01-01 09:00:00              746
# 2                      0.1  2019-01-01 10:00:00              747
# 3                      0.1  2019-01-01 11:00:00              748
# 4                      0.1  2019-01-01 12:00:00              749
#
#    air_density_wind  wind_speed_wind  kWh_wind_power_wind sheet_wind  \
# 0             1.335            6.178             1203.800     Sheet1
# 1             1.337            6.534             1410.415     Sheet1
# 2             1.339            6.747             1547.633     Sheet1
# 3             1.340            6.765             1556.072     Sheet1
# 4             1.342            6.606             1456.741     Sheet1
#
#   season_derived  year  month  day  hour  doy  week
# 0         winter  2019      1    1     8    1     1
# 1         winter  2019      1    1     9    1     1
# 2         winter  2019      1    1    10    1     1
# 3         winter  2019      1    1    11    1     1
# 4         winter  2019      1    1    12    1     1

# %%
if "timestamp" in df.columns:
    if "hour" not in df.columns:
        df["hour"] = pd.to_datetime(df["timestamp"], errors="coerce").dt.hour
    if "month" not in df.columns:
        df["month"] = pd.to_datetime(df["timestamp"], errors="coerce").dt.month

def _hourly_means(series: pd.Series):
    s = pd.to_numeric(series, errors="coerce")
    tmp = pd.DataFrame({"val": s, "hour": df["hour"]}).dropna()
    if tmp.empty:
        return None
    return tmp.groupby("hour")["val"].mean()

def _monthly_means(series: pd.Series):
    s = pd.to_numeric(series, errors="coerce")
    tmp = pd.DataFrame({"val": s, "month": df["month"]}).dropna()
    if tmp.empty:
        return None
    
    return tmp.groupby("month")["val"].mean().reindex(range(1, 13))

# %%
def report_count(name, cond):
    n = int(cond.sum())
    print(f"{name}: {n}")


if "hour" in df.columns:
    night = df["hour"].isin([0,1,2,3,4,5,20,21,22,23])

    if "surface_irradiance_solar" in df.columns:
        irr = pd.to_numeric(df["surface_irradiance_solar"], errors="coerce")
        report_count("Night irradiance > 0", (irr > 0) & night)

    if solar_target:
        sp = pd.to_numeric(df[solar_target], errors="coerce")
        report_count("Night solar power > 0", (sp > 0) & night)


if "wind_speed_wind" in df.columns:
    ws = pd.to_numeric(df["wind_speed_wind"], errors="coerce")
    report_count("Negative wind speed", ws < 0)

if solar_target:
    sp = pd.to_numeric(df[solar_target], errors="coerce")
    report_count("Negative solar power", sp < 0)

if wind_target:
    wp = pd.to_numeric(df[wind_target], errors="coerce")
    report_count("Negative wind power", wp < 0)
# Out:
# Night irradiance > 0: 579
# Night solar power > 0: 354
# Negative wind speed: 0
# Negative solar power: 0
# Negative wind power: 0

# %%
feature_candidates = []
feature_candidates += solar_feats
feature_candidates += wind_feats

for c in ["month", "hour", "doy"]:
    if c in df.columns:
        feature_candidates.append(c)


m = df.dropna(subset=["timestamp"]).copy()
m = m.drop_duplicates(subset=["timestamp"])


def make_Xy(data: pd.DataFrame, target_col: str, features: list):
    X = data[features].copy()
    y = pd.to_numeric(data[target_col], errors="coerce")
    
    mask = (~y.isna())
    for c in X.columns:
        mask &= ~X[c].isna()
    X = X[mask]
    y = y[mask]
    return X, y

X_solar, y_solar = (None, None)
X_wind,  y_wind  = (None, None)

if solar_target:
    X_solar, y_solar = make_Xy(m, solar_target, [c for c in feature_candidates if c in m.columns])
    print("Solar X/y:", X_solar.shape, y_solar.shape)

if wind_target:
    X_wind, y_wind = make_Xy(m, wind_target, [c for c in feature_candidates if c in m.columns])
    print("Wind  X/y:", X_wind.shape, y_wind.shape)


def time_split(df_like: pd.DataFrame, frac_test=0.2):
    n = len(df_like)
    cut = int(np.floor(n*(1-frac_test)))
    idx = np.arange(n)
    return idx[:cut], idx[cut:]

if X_solar is not None:
    idx_tr, idx_te = time_split(X_solar, 0.2)
    print("Solar split:", len(idx_tr), "train /", len(idx_te), "test")

if X_wind is not None:
    idx_tr, idx_te = time_split(X_wind, 0.2)
    print("Wind split:", len(idx_tr), "train /", len(idx_te), "test")
# Out:
# Solar X/y: (8752, 11) (8752,)
# Wind  X/y: (8752, 11) (8752,)
# Solar split: 7001 train / 1751 test
# Wind split: 7001 train / 1751 test

# %%
# ===== Fragment 13: Tables for the paper =====
def seasonal_stats(series: pd.Series, name: str):
    s = pd.to_numeric(series, errors="coerce")
    t = pd.DataFrame({"val": s, "season": df["season_derived"]}).dropna()
    if t.empty:
        return
    g = t.groupby("season")["val"].agg(["count","mean","std","min","max"])
    print(f"\nSeasonal stats — {name}")
    print(g)

def monthly_stats(series: pd.Series, name: str):
    s = pd.to_numeric(series, errors="coerce")
    t = pd.DataFrame({"val": s, "month": df["month"]}).dropna()
    if t.empty:
        return
    g = t.groupby("month")["val"].agg(["count","mean","std","min","max"])
    print(f"\nMonthly stats — {name}")
    print(g)

if solar_target:
    seasonal_stats(df[solar_target], "Solar Power (kW)")
    monthly_stats(df[solar_target], "Solar Power (kW)")

if wind_target:
    seasonal_stats(df[wind_target], "Wind Power (kW)")
    monthly_stats(df[wind_target], "Wind Power (kW)")


def table_top_corr(target, k=10, method="pearson"):
    if (target is None) or (target not in df.columns):
        return
    num_df = df.select_dtypes(include=[np.number]).copy()
    corr = num_df.corr(method=method)[target].drop(target).sort_values(ascending=False)
    top = corr.head(k).to_frame(f"corr_with_{target}_{method}")
    print(top)

table_top_corr(solar_target, 10, "pearson")
table_top_corr(solar_target, 10, "spearman")
table_top_corr(wind_target,  10, "pearson")
table_top_corr(wind_target,  10, "spearman")
# Out:
# Seasonal stats — Solar Power (kW)
#         count         mean          std  min       max
# season
# autumn   2184   942.717727  1377.896308  0.0  4238.193
# spring   2209  1161.535002  1462.703420  0.0  4500.000
# summer   2208   966.957184  1200.696901  0.0  4036.684
# winter   2152   721.235507  1237.513954  0.0  4500.000
#
# Monthly stats — Solar Power (kW)
#        count         mean          std  min       max
# month
# 1        736   685.842629  1177.053979  0.0  4005.425
# 2        672  1061.194115  1543.353973  0.0  4500.000
# 3        744  1050.507254  1467.837257  0.0  4500.000
# 4        720  1318.606440  1544.096468  0.0  4500.000
# 5        745  1120.613136  1362.291924  0.0  4300.442
# 6        720  1144.471549  1320.815891  0.0  4036.684
# 7        744  1000.190301  1185.015244  0.0  3742.922
# 8        744   761.935972  1056.473145  0.0  3886.848
# 9        720  1196.589754  1485.146683  0.0  4197.958
# 10       744   975.909679  1418.051224  0.0  4238.193
# 11       720   654.547349  1154.105752  0.0  4020.070
# 12       744   449.188427   855.578470  0.0  3686.342
#
# Seasonal stats — Wind Power (kW)
#         count         mean          std  min       max
# season
# autumn   2184  1605.857070  1209.599530  0.0  4839.045
# spring   2209  1854.045195  1399.721278  0.0  4956.556
# summer   2208   969.967441   866.407289  0.0  4242.969
# winter   2152  1216.700367  1079.487498  0.0  4835.979
#
# Monthly stats — Wind Power (kW)
#        count         mean          std    min       max
# month
# 1        736  1301.014217  1130.715143  0.003  4602.714
# 2        672  1508.814920  1162.347173  0.000  4835.979
# 3        744  1391.723345  1241.018233  0.005  4623.053
# 4        720  1957.877840  1389.774365  0.018  4925.334
# 5        745  2215.398150  1433.493846  0.000  4956.556
# 6        720  1230.441842  1031.073290  0.000  4242.969
# 7        744   883.253534   740.424718  0.000  3589.265
# 8        744   804.609348   743.034940  0.000  3979.145
# 9        720  1479.775468  1261.323306  0.000  4839.045
# 10       744  1689.370056  1178.142883  0.000  4733.363
# 11       720  1645.641918  1179.954390  0.045  4802.391
# 12       744   869.447715   826.863525  0.000  3932.279
#                           corr_with_kWh_solar_power_solar_pearson
# surface_irradiance_solar                                 0.877205
# toa_irradiance_solar                                     0.789576
# temperature_solar                                        0.266562
# kWh_wind_power_wind                                      0.044851
# wind_speed_wind                                          0.031430
# relative_humidity_solar                                  0.026410
# humidity_solar                                           0.026410
# specific_humidity_solar                                  0.026410
# day                                                     -0.024913
# hour_index_solar                                        -0.025681
#                           corr_with_kWh_solar_power_solar_spearman
# surface_irradiance_solar                                  0.944044
# toa_irradiance_solar                                      0.914781
# temperature_solar                                         0.326327
# humidity_solar                                            0.129282
# specific_humidity_solar                                   0.129282
# relative_humidity_solar                                   0.129282
# day                                                      -0.013263
# hour_index_solar                                         -0.014072
# hour_index_wind                                          -0.014072
# wind_speed_wind                                          -0.021856
#                           corr_with_kWh_wind_power_wind_pearson
# wind_speed_wind                                        0.972929
# hour                                                   0.136769
# hour_index_wind                                        0.111420
# hour_index_solar                                       0.111420
# surface_irradiance_solar                               0.056172
# toa_irradiance_solar                                   0.046937
# kWh_solar_power_solar                                  0.044851
# temperature_solar                                      0.036773
# day                                                    0.036121
# air_density_wind                                       0.000583
#                           corr_with_kWh_wind_power_wind_spearman
# wind_speed_wind                                         1.000000
# hour                                                    0.130012
# hour_index_solar                                        0.106100
# hour_index_wind                                         0.106100
# air_density_wind                                        0.040034
# day                                                     0.022688
# temperature_solar                                      -0.003537
# surface_irradiance_solar                               -0.010328
# toa_irradiance_solar                                   -0.010989
# kWh_solar_power_solar                                  -0.021861

# %%
def _find_target(cols, suffix):
    cands = [c for c in cols if c.lower().endswith(suffix) and ("kw" in c.lower()) and ("power" in c.lower())]
    if cands: return cands[0]
    # запасной вариант: любое "power_*suffix"
    cands = [c for c in cols if c.lower().endswith(suffix) and ("power" in c.lower())]
    return cands[0] if cands else None

cols = df.columns.tolist()
target_solar = _find_target(cols, "_solar") 
target_wind  = _find_target(cols, "_wind")  

assert target_solar is not None, "Не найден столбец таргета для солнца"
assert target_wind  is not None, "Не найден столбец таргета для ветра"

base_feature_keys = [

    "surface_irradiance_solar","toa_irradiance_solar","irradiance_solar",
    "temperature_solar","module_temperature_solar",
    "humidity_solar","relative_humidity_solar","specific_humidity_solar",

    "wind_speed_wind","wind_direction_wind","air_density_wind",

    "hour","month","doy"
]
features_all = [c for c in base_feature_keys if c in df.columns]

m = df.dropna(subset=features_all + [target_solar, target_wind]).copy()


X = m[features_all].copy()
y_solar = m[target_solar].astype(float)
y_wind  = m[target_wind].astype(float)

print("Targets:", target_solar, "|", target_wind)
print("Shared features:", features_all)
print("Shapes:", X.shape, y_solar.shape, y_wind.shape)


def time_split(n, frac_test=0.2):
    cut = int(n * (1 - frac_test))
    idx_tr = np.arange(cut)
    idx_te = np.arange(cut, n)
    return idx_tr, idx_te

idx_tr, idx_te = time_split(len(X), 0.2)
Xtr, Xte = X.iloc[idx_tr], X.iloc[idx_te]
ys_tr, ys_te = y_solar.iloc[idx_tr], y_solar.iloc[idx_te]
yw_tr, yw_te = y_wind.iloc[idx_tr],  y_wind.iloc[idx_te]
# Out:
# Targets: kWh_solar_power_solar | kWh_wind_power_wind
# Shared features: ['surface_irradiance_solar', 'toa_irradiance_solar', 'temperature_solar', 'humidity_solar', 'relative_humidity_solar', 'specific_humidity_solar', 'wind_speed_wind', 'air_density_wind', 'hour', 'month', 'doy']
# Shapes: (8753, 11) (8753,) (8753,)

# %%
# ===== 0. Common setup (metrics, splits, CV & report) =====
import numpy as np, pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, explained_variance_score
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler

def _mape(y_true, y_pred, eps=1e-8):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    m = np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None)).mean()
    return m * 100.0

def compute_metrics(y_true, y_pred):
    mse  = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_true, y_pred)
    mape = _mape(y_true, y_pred)
    r2   = r2_score(y_true, y_pred)
    evs  = explained_variance_score(y_true, y_pred)
    return {"MSE":mse, "RMSE":rmse, "MAE":mae, "MAPE%":mape, "R2":r2, "EVS":evs}


def summarize_cv(cv_metrics_list):
    keys = list(cv_metrics_list[0].keys())
    agg = {}
    n = len(cv_metrics_list)
    for k in keys:
        vals = np.array([d[k] for d in cv_metrics_list], float)
        mean = vals.mean()
        std  = vals.std(ddof=1) if n>1 else 0.0
        from math import sqrt
        from scipy.stats import t
        alpha = 0.10
        tcrit = t.ppf(1 - alpha/2, df=max(n-1,1))
        margin = tcrit * std / sqrt(n) if n>1 else 0.0
        agg[k] = {"mean":mean, "std":std, "CI90_low":mean-margin, "CI90_high":mean+margin}
    return pd.DataFrame(agg).T

# ---- 80/20  ----
def train_test_time_split(y, frac_test=0.2, X_exog=None):
    n = len(y)
    cut = int(np.floor(n*(1-frac_test)))
    sl_tr = slice(0, cut)
    sl_te = slice(cut, n)
    if X_exog is None:
        return (y.iloc[sl_tr], y.iloc[sl_te], None, None)
    else:
        return (y.iloc[sl_tr], y.iloc[sl_te],
                X_exog.iloc[sl_tr] if isinstance(X_exog, pd.DataFrame) else X_exog[sl_tr],
                X_exog.iloc[sl_te]  if isinstance(X_exog, pd.DataFrame) else X_exog[sl_te])

# ---- 5-fold TimeSeriesSplit ----
def folds_time_series(n_splits=5):
    return TimeSeriesSplit(n_splits=n_splits)


report_rows = []

# %%
# ===== ONE-FRAGMENT — Spatio-Temporal Transformer (STT) [VERBOSE] =====
# Anti-leakage: train-only winsorize/scale; train-only extreme thresholds
# Causality: flat_in = last step of the window (i-1)
# Stability: fixed seeds; safe AUC; gradient clipping
# Visibility: verbose Keras logs (Epoch/steps, per-output losses) + printed summaries

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"   

import numpy as np, pandas as pd
from scipy.stats import t
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import (mean_squared_error, mean_absolute_error, r2_score,
                             explained_variance_score, roc_auc_score)

import tensorflow as tf
from tensorflow.keras.layers import (Input, Dense, BatchNormalization, Dropout, Add,
                                     LayerNormalization, GlobalAveragePooling1D,
                                     MultiHeadAttention)
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K


tf.keras.utils.set_random_seed(42)


def _sign_log1p_df(df_):
    A = df_.astype(float).copy()
    return np.sign(A) * np.log1p(np.abs(A))

def _train_only_preprocess(Xtr_raw: pd.DataFrame, Xte_raw: pd.DataFrame):
    """Winsorize по train-квантилям, затем sign-log1p, затем MinMaxScaler.fit(train)."""
    q_low, q_high = Xtr_raw.quantile(0.01), Xtr_raw.quantile(0.99)
    Xtr_raw = Xtr_raw.clip(lower=q_low, upper=q_high, axis=1)
    Xte_raw = Xte_raw.clip(lower=q_low, upper=q_high, axis=1)

    Xtr_t = _sign_log1p_df(Xtr_raw).values
    Xte_t = _sign_log1p_df(Xte_raw).values

    scaler = MinMaxScaler().fit(Xtr_t)
    Xtr = scaler.transform(Xtr_t)
    Xte = scaler.transform(Xte_t)
    return Xtr, Xte

def preprocess(df, features_all, y_solar, y_wind):
    """Совместимость API: возвращаем X_scaled-заглушку и y в sign-log1p."""
    X = df[features_all].astype(float)
    X_scaled = np.zeros_like(X.values, dtype=float)  
    def _log_tr(y):
        y = np.asarray(y).astype(float)
        return np.where(y >= 0, np.log1p(y), -np.log1p(np.abs(y)))
    return X_scaled, _log_tr(y_solar).ravel(), _log_tr(y_wind).ravel()

def make_seq(X, L):
    out=[]
    for i in range(len(X)):
        seq = X[max(0,i-L):i]
        if len(seq)<L: seq = np.pad(seq, ((L-len(seq),0),(0,0)), 'constant')
        out.append(seq)
    return np.stack(out)

def safe_mape(y_true,y_pred,eps=1e-8):
    y_true, y_pred = np.asarray(y_true), np.asarray(y_pred)
    m = np.abs(y_true) > eps
    if m.sum()==0: return np.nan
    return np.mean(np.abs((y_true[m]-y_pred[m])/y_true[m]))*100.0

def safe_auc(y_true_bin, y_score):
    y_true_bin = np.asarray(y_true_bin).astype(int)
    p = int(y_true_bin.sum()); n = int(len(y_true_bin)-p)
    if p==0 or n==0: return np.nan
    return roc_auc_score(y_true_bin, y_score)


class LossScaleLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.log_var_solar_reg = self.add_weight("log_var_solar_reg", initializer="zeros", trainable=True)
        self.log_var_wind_reg  = self.add_weight("log_var_wind_reg",  initializer="zeros", trainable=True)
    def call(self, z): return z

def _u_mse(log_var, l2=1e-4, clip_min=-3.0, clip_max=3.0):
    def loss(y_true, y_pred):
        lv  = tf.clip_by_value(log_var, clip_min, clip_max)
        mse = tf.reduce_mean(tf.square(y_true - y_pred))
        return tf.exp(-lv)*mse + lv + l2*tf.square(lv)
    return loss

try:
    FocalBCE = tf.keras.losses.BinaryFocalCrossentropy
    focal_bce = FocalBCE(gamma=2.0, reduction=tf.keras.losses.Reduction.SUM_OVER_BATCH_SIZE)
except Exception:
    focal_bce = tf.keras.losses.BinaryCrossentropy()


class TimePositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, d_model: int, **kwargs):
        super().__init__(**kwargs)
        self.d_model = int(d_model)
    def build(self, input_shape):
        d = self.d_model
        i = tf.range(d)[tf.newaxis, :]
        self.i_float = tf.cast(i, tf.float32)
        self.even_mask = tf.cast((i % 2) == 0, tf.bool)
        self.d_float = tf.cast(d, tf.float32)
        self.const_10000 = tf.constant(10000.0, tf.float32)
        super().build(input_shape)
    def _den(self, i_float):
        return tf.pow(self.const_10000, (2.0 * tf.math.floor(i_float / 2.0)) / self.d_float)
    def call(self, x):

        B = tf.shape(x)[0]; L = tf.shape(x)[1]
        pos = tf.cast(tf.range(L)[:, tf.newaxis], tf.float32)      # (L,1)
        angles = pos / self._den(self.i_float)                      # (L,d)
        sin_t, cos_t = tf.sin(angles), tf.cos(angles)
        pe = tf.where(self.even_mask, sin_t, cos_t)                 # (L,d)
        pe = tf.tile(pe[tf.newaxis, ...], [B, 1, 1])                # (B,L,d)
        return x + pe


def transformer_encoder_block(x, num_heads=4, d_model=32,
                              ff_dim1=64, ff_dim2=32, dropout_rate=0.1, eps=1e-5, causal=True):
    key_dim = max(1, d_model // num_heads)  
    x_norm = LayerNormalization(epsilon=eps)(x)
    attn = MultiHeadAttention(num_heads=num_heads, key_dim=key_dim, dropout=dropout_rate)(
        x_norm, x_norm, use_causal_mask=causal
    )
    x = Add()([x, attn])
    x_norm = LayerNormalization(epsilon=eps)(x)
    ff  = Dense(ff_dim1, activation="relu")(x_norm)
    ff  = Dense(ff_dim2, activation=None)(ff)
    ff  = Dropout(dropout_rate)(ff)
    x = Add()([x, ff])
    return LayerNormalization(epsilon=eps)(x)


def build_st_transformer(input_shapes, d_model=32, num_heads=4, n_blocks=4,
                         dropout_rate=0.1, lr=1e-3):
    """
    input_shapes: {'seq': (L, D), 'flat': (D,)} — flat оставлен для совместимости API
    """
    L, D = input_shapes['seq']
    seq_in  = Input(shape=(L, D), name="seq_in")
    flat_in = Input(shape=(D,),   name="flat_in") 
    z = Dense(d_model, name="stt_proj")(seq_in)            
    z = TimePositionalEncoding(d_model=d_model, name="TimePE")(z)
    for _ in range(n_blocks):
        z = transformer_encoder_block(z, num_heads=num_heads, d_model=d_model,
                                      ff_dim1=64, ff_dim2=d_model,
                                      dropout_rate=dropout_rate, eps=1e-5, causal=True)
    z = GlobalAveragePooling1D(name="stt_gap")(z)
    z = BatchNormalization(name="bn_after_gap")(z)
    z = Dense(64, activation="relu")(z)
    z = Dropout(0.2)(z)

    z = LossScaleLayer(name="loss_scales")(z)

    solar_reg = Dense(1, name="solar_reg")(z)
    wind_reg  = Dense(1, name="wind_reg")(z)
    solar_ext = Dense(1, activation="sigmoid", name="solar_ext")(z)
    wind_ext  = Dense(1, activation="sigmoid", name="wind_ext")(z)

    model = Model(inputs=[seq_in, flat_in],
                  outputs=[solar_reg, wind_reg, solar_ext, wind_ext],
                  name="SpatioTemporalTransformer")

    lw = model.get_layer("loss_scales")
    losses = {
        "solar_reg": _u_mse(lw.log_var_solar_reg),
        "wind_reg":  _u_mse(lw.log_var_wind_reg),
        "solar_ext": focal_bce,
        "wind_ext":  focal_bce,
    }

    opt = Adam(learning_rate=lr, clipnorm=1.0)   
    model.compile(optimizer=opt, loss=losses)
    return model


def run_stt_holdout(df, features_all, y_solar, y_wind,
                    n_steps=24, epochs=20, batch=64, lr=1e-3, verbose=1):
    _, ys_all, yw_all = preprocess(df, features_all, y_solar, y_wind)

    cut = int(len(df)*0.8)
    Xtr_raw, Xte_raw = df.iloc[:cut][features_all].copy(), df.iloc[cut:][features_all].copy()
    Xtr, Xte = _train_only_preprocess(Xtr_raw, Xte_raw)

    ys_tr, ys_te = ys_all[:cut], ys_all[cut:]
    yw_tr, yw_te = yw_all[:cut], yw_all[cut:]

    L = min(n_steps, len(Xtr))
    Xtr_seq, Xte_seq = make_seq(Xtr, L), make_seq(Xte, L)
    Xtr_flat, Xte_flat = Xtr_seq[:, -1, :], Xte_seq[:, -1, :]

    thr_s = np.percentile(ys_tr, 95); thr_w = np.percentile(yw_tr, 95)
    ys_tr_ext = (ys_tr > thr_s).astype(int); ys_te_ext = (ys_te > thr_s).astype(int)
    yw_tr_ext = (yw_tr > thr_w).astype(int); yw_te_ext = (yw_te > thr_w).astype(int)

    model = build_st_transformer({'seq':(L, Xtr.shape[1]), 'flat':(Xtr.shape[1],)}, lr=lr)

    # печатаем эпохи/шаги
    model.fit([Xtr_seq, Xtr_flat],
              {"solar_reg": ys_tr, "wind_reg": yw_tr,
               "solar_ext": ys_tr_ext, "wind_ext": yw_tr_ext},
              validation_data=([Xte_seq, Xte_flat],
                               {"solar_reg": ys_te, "wind_reg": yw_te,
                                "solar_ext": ys_te_ext, "wind_ext": yw_te_ext}),
              epochs=epochs, batch_size=batch, verbose=verbose)

    pr = model.predict([Xte_seq, Xte_flat], verbose=1)
    s_pred, w_pred = pr[0].ravel(), pr[1].ravel()
    s_ext,  w_ext  = pr[2].ravel(), pr[3].ravel()

    metrics = {
        "Solar": {"RMSE": np.sqrt(mean_squared_error(ys_te, s_pred)),
                  "MAE":  mean_absolute_error(ys_te, s_pred),
                  "MAPE": safe_mape(ys_te, s_pred),
                  "R2":   r2_score(ys_te, s_pred),
                  "EVS":  explained_variance_score(ys_te, s_pred),
                  "AUC":  safe_auc(ys_te_ext, s_ext)},
        "Wind":  {"RMSE": np.sqrt(mean_squared_error(yw_te, w_pred)),
                  "MAE":  mean_absolute_error(yw_te, w_pred),
                  "MAPE": safe_mape(yw_te, w_pred),
                  "R2":   r2_score(yw_te, w_pred),
                  "EVS":  explained_variance_score(yw_te, w_pred),
                  "AUC":  safe_auc(yw_te_ext, w_ext)}
    }
    print("\n=== Holdout 80/20 ===")
    print(pd.DataFrame(metrics).T)
    return metrics


def run_stt_cv(df, features_all, y_solar, y_wind,
               n_steps=24, epochs=20, batch=64, lr=1e-3, n_splits=5, verbose=1):
    _, ys_all, yw_all = preprocess(df, features_all, y_solar, y_wind)
    tscv = TimeSeriesSplit(n_splits=n_splits)

    scores_s, scores_w, aucs = [], [], []
    for f,(tr,te) in enumerate(tscv.split(df), 1):
        print(f"\nFOLD {f}")
        K.clear_session()
        tf.keras.utils.set_random_seed(42 + f)

        Xtr_raw, Xte_raw = df.iloc[tr][features_all].copy(), df.iloc[te][features_all].copy()
        Xtr, Xte = _train_only_preprocess(Xtr_raw, Xte_raw)

        ys_tr, ys_te = ys_all[tr], ys_all[te]
        yw_tr, yw_te = yw_all[tr], yw_all[te]

        L = min(n_steps, len(Xtr))
        Xtr_seq, Xte_seq = make_seq(Xtr, L), make_seq(Xte, L)
        Xtr_flat, Xte_flat = Xtr_seq[:, -1, :], Xte_seq[:, -1, :]

        thr_s = np.percentile(ys_tr, 95); thr_w = np.percentile(yw_tr, 95)
        ys_tr_ext = (ys_tr > thr_s).astype(int); ys_te_ext = (ys_te > thr_s).astype(int)
        yw_tr_ext = (yw_tr > thr_w).astype(int); yw_te_ext = (yw_te > thr_w).astype(int)

        m = build_st_transformer({'seq':(L, Xtr.shape[1]), 'flat':(Xtr.shape[1],)}, lr=lr)

        m.fit([Xtr_seq, Xtr_flat],
              {"solar_reg": ys_tr, "wind_reg": yw_tr,
               "solar_ext": ys_tr_ext, "wind_ext": yw_tr_ext},
              epochs=epochs, batch_size=batch, verbose=verbose)

        _ = m.predict([Xte_seq, Xte_flat], verbose=1)  
        pr = m.predict([Xte_seq, Xte_flat], verbose=0) 
        s_pred, w_pred = pr[0].ravel(), pr[1].ravel()
        s_ext,  w_ext  = pr[2].ravel(), pr[3].ravel()

        ms = {"MSE": mean_squared_error(ys_te, s_pred),
              "RMSE": np.sqrt(mean_squared_error(ys_te, s_pred)),
              "MAE": mean_absolute_error(ys_te, s_pred),
              "MAPE": safe_mape(ys_te, s_pred),
              "R2": r2_score(ys_te, s_pred),
              "EVS": explained_variance_score(ys_te, s_pred)}
        mw = {"MSE": mean_squared_error(yw_te, w_pred),
              "RMSE": np.sqrt(mean_squared_error(yw_te, w_pred)),
              "MAE": mean_absolute_error(yw_te, w_pred),
              "MAPE": safe_mape(yw_te, w_pred),
              "R2": r2_score(yw_te, w_pred),
              "EVS": explained_variance_score(yw_te, w_pred)}
        scores_s.append(ms); scores_w.append(mw)
        aucs.append({"AUC_s": safe_auc(ys_te_ext, s_ext),
                     "AUC_w": safe_auc(yw_te_ext, w_ext)})

        print(f"Solar fold {f}: {ms}")
        print(f"Wind  fold {f}: {mw}")

    df_s = pd.DataFrame(scores_s); df_w = pd.DataFrame(scores_w); df_auc = pd.DataFrame(aucs)

    def summarize(dfm):
        n=len(dfm); m=dfm.mean(); sd=dfm.std(ddof=1)
        tcrit=t.ppf(1-0.05, df=max(n-1,1))
        low=m - tcrit*sd/np.sqrt(max(n,1)); high=m + tcrit*sd/np.sqrt(max(n,1))
        return pd.concat([m.rename('mean'), sd.rename('std'),
                          low.rename('CI90_low'), high.rename('CI90_high')], axis=1)

    print("\n=== CV Summary Solar ==="); print(summarize(df_s))
    print("\n=== CV Summary Wind ===");  print(summarize(df_w))
    print("\n=== CV Summary AUCs ===");  print(df_auc.mean(numeric_only=True))
    return df_s, df_w, df_auc


hold = run_stt_holdout(df, features_all, y_solar, y_wind,
                       n_steps=24, epochs=20, batch=64, lr=1e-3, verbose=1)
cv_s, cv_w, cv_auc = run_stt_cv(df, features_all, y_solar, y_wind,
                                n_steps=24, epochs=20, batch=64, lr=1e-3, n_splits=5, verbose=1)
# Out:
# Epoch 1/20
# 2025-09-02 12:23:28.893721: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 110/110 [==============================] - 24s 144ms/step - loss: 56.1002 - solar_reg_loss: 20.1488 - wind_reg_loss: 35.1802 - solar_ext_loss: 0.3940 - wind_ext_loss: 0.3772 - val_loss: 38.9220 - val_solar_reg_loss: 17.1900 - val_wind_reg_loss: 21.6181 - val_solar_ext_loss: 0.0558 - val_wind_ext_loss: 0.0581
# Epoch 2/20
# 110/110 [==============================] - 13s 115ms/step - loss: 37.7264 - solar_reg_loss: 15.3102 - wind_reg_loss: 21.6271 - solar_ext_loss: 0.4364 - wind_ext_loss: 0.3526 - val_loss: 33.2900 - val_solar_reg_loss: 23.3324 - val_wind_reg_loss: 9.8638 - val_solar_ext_loss: 0.0165 - val_wind_ext_loss: 0.0772
# Epoch 3/20
# 110/110 [==============================] - 13s 118ms/step - loss: 24.8558 - solar_reg_loss: 9.6946 - wind_reg_loss: 14.6932 - solar_ext_loss: 0.2337 - wind_ext_loss: 0.2343 - val_loss: 90.6249 - val_solar_reg_loss: 26.9620 - val_wind_reg_loss: 63.4483 - val_solar_ext_loss: 0.0140 - val_wind_ext_loss: 0.2007
# Epoch 4/20
# 110/110 [==============================] - 13s 115ms/step - loss: 25.3037 - solar_reg_loss: 9.7296 - wind_reg_loss: 15.2364 - solar_ext_loss: 0.1467 - wind_ext_loss: 0.1911 - val_loss: 86.0933 - val_solar_reg_loss: 4.6671 - val_wind_reg_loss: 78.0314 - val_solar_ext_loss: 2.9251 - val_wind_ext_loss: 0.4697
# Epoch 5/20
# 110/110 [==============================] - 13s 114ms/step - loss: 29.6803 - solar_reg_loss: 10.1448 - wind_reg_loss: 19.1906 - solar_ext_loss: 0.1588 - wind_ext_loss: 0.1862 - val_loss: 25.3980 - val_solar_reg_loss: 6.8110 - val_wind_reg_loss: 18.5069 - val_solar_ext_loss: 0.0172 - val_wind_ext_loss: 0.0629
# Epoch 6/20
# 110/110 [==============================] - 13s 121ms/step - loss: 21.5447 - solar_reg_loss: 7.0631 - wind_reg_loss: 14.1010 - solar_ext_loss: 0.2028 - wind_ext_loss: 0.1777 - val_loss: 41.3778 - val_solar_reg_loss: 6.8877 - val_wind_reg_loss: 34.2515 - val_solar_ext_loss: 0.1948 - val_wind_ext_loss: 0.0438
# Epoch 7/20
# 110/110 [==============================] - 13s 117ms/step - loss: 16.1419 - solar_reg_loss: 5.2303 - wind_reg_loss: 10.7015 - solar_ext_loss: 0.0933 - wind_ext_loss: 0.1168 - val_loss: 156.8505 - val_solar_reg_loss: 33.7727 - val_wind_reg_loss: 118.3667 - val_solar_ext_loss: 2.8563 - val_wind_ext_loss: 1.8548
# Epoch 8/20
# 110/110 [==============================] - 13s 118ms/step - loss: 7.6425 - solar_reg_loss: 2.9267 - wind_reg_loss: 4.5467 - solar_ext_loss: 0.0751 - wind_ext_loss: 0.0940 - val_loss: 69.0999 - val_solar_reg_loss: 38.7378 - val_wind_reg_loss: 30.0584 - val_solar_ext_loss: 0.0478 - val_wind_ext_loss: 0.2559
# Epoch 9/20
# 110/110 [==============================] - 13s 116ms/step - loss: 9.7296 - solar_reg_loss: 3.6587 - wind_reg_loss: 5.8924 - solar_ext_loss: 0.0888 - wind_ext_loss: 0.0897 - val_loss: 19.2764 - val_solar_reg_loss: 9.3735 - val_wind_reg_loss: 9.2372 - val_solar_ext_loss: 0.4947 - val_wind_ext_loss: 0.1709
# Epoch 10/20
# 110/110 [==============================] - 12s 113ms/step - loss: 12.4538 - solar_reg_loss: 4.0410 - wind_reg_loss: 8.2320 - solar_ext_loss: 0.0954 - wind_ext_loss: 0.0854 - val_loss: 87.4626 - val_solar_reg_loss: 3.5118 - val_wind_reg_loss: 79.9810 - val_solar_ext_loss: 3.8958 - val_wind_ext_loss: 0.0741
# Epoch 11/20
# 110/110 [==============================] - 12s 113ms/step - loss: 10.7660 - solar_reg_loss: 2.9296 - wind_reg_loss: 7.6788 - solar_ext_loss: 0.0846 - wind_ext_loss: 0.0730 - val_loss: 75.2884 - val_solar_reg_loss: 24.1079 - val_wind_reg_loss: 47.2613 - val_solar_ext_loss: 1.5424 - val_wind_ext_loss: 2.3768
# Epoch 12/20
# 110/110 [==============================] - 13s 119ms/step - loss: 8.9689 - solar_reg_loss: 3.4152 - wind_reg_loss: 5.3856 - solar_ext_loss: 0.0925 - wind_ext_loss: 0.0755 - val_loss: 66.6689 - val_solar_reg_loss: 49.7896 - val_wind_reg_loss: 16.7728 - val_solar_ext_loss: 0.0124 - val_wind_ext_loss: 0.0940
# Epoch 13/20
# 110/110 [==============================] - 13s 116ms/step - loss: 6.2986 - solar_reg_loss: 2.2466 - wind_reg_loss: 3.8994 - solar_ext_loss: 0.0781 - wind_ext_loss: 0.0745 - val_loss: 3.9641 - val_solar_reg_loss: 1.7987 - val_wind_reg_loss: 2.1126 - val_solar_ext_loss: 0.0113 - val_wind_ext_loss: 0.0415
# Epoch 14/20
# 110/110 [==============================] - 14s 125ms/step - loss: 4.6323 - solar_reg_loss: 1.8309 - wind_reg_loss: 2.6707 - solar_ext_loss: 0.0589 - wind_ext_loss: 0.0718 - val_loss: 11.8942 - val_solar_reg_loss: 9.5019 - val_wind_reg_loss: 2.2731 - val_solar_ext_loss: 0.0789 - val_wind_ext_loss: 0.0404
# Epoch 15/20
# 110/110 [==============================] - 13s 120ms/step - loss: 4.2787 - solar_reg_loss: 1.7666 - wind_reg_loss: 2.3762 - solar_ext_loss: 0.0637 - wind_ext_loss: 0.0722 - val_loss: 5.5749 - val_solar_reg_loss: 3.2682 - val_wind_reg_loss: 2.2144 - val_solar_ext_loss: 0.0468 - val_wind_ext_loss: 0.0454
# Epoch 16/20
# 110/110 [==============================] - 13s 118ms/step - loss: 4.5692 - solar_reg_loss: 1.7894 - wind_reg_loss: 2.6422 - solar_ext_loss: 0.0663 - wind_ext_loss: 0.0713 - val_loss: 7.8978 - val_solar_reg_loss: 3.5451 - val_wind_reg_loss: 4.2951 - val_solar_ext_loss: 0.0117 - val_wind_ext_loss: 0.0460
# Epoch 17/20
# 110/110 [==============================] - 14s 124ms/step - loss: 9.9791 - solar_reg_loss: 3.1700 - wind_reg_loss: 6.6276 - solar_ext_loss: 0.0906 - wind_ext_loss: 0.0909 - val_loss: 18.9892 - val_solar_reg_loss: 10.7959 - val_wind_reg_loss: 8.1227 - val_solar_ext_loss: 0.0262 - val_wind_ext_loss: 0.0443
# Epoch 18/20
# 110/110 [==============================] - 13s 121ms/step - loss: 13.8595 - solar_reg_loss: 3.9244 - wind_reg_loss: 9.6787 - solar_ext_loss: 0.1366 - wind_ext_loss: 0.1198 - val_loss: 22.2589 - val_solar_reg_loss: 18.1621 - val_wind_reg_loss: 3.9749 - val_solar_ext_loss: 0.0270 - val_wind_ext_loss: 0.0949
# Epoch 19/20
# 110/110 [==============================] - 13s 119ms/step - loss: 16.5467 - solar_reg_loss: 3.4631 - wind_reg_loss: 12.8359 - solar_ext_loss: 0.1266 - wind_ext_loss: 0.1210 - val_loss: 15.9965 - val_solar_reg_loss: 4.6117 - val_wind_reg_loss: 11.3103 - val_solar_ext_loss: 0.0173 - val_wind_ext_loss: 0.0573
# Epoch 20/20
# 110/110 [==============================] - 13s 122ms/step - loss: 22.4187 - solar_reg_loss: 3.8702 - wind_reg_loss: 18.2590 - solar_ext_loss: 0.1469 - wind_ext_loss: 0.1427 - val_loss: 7.6911 - val_solar_reg_loss: 2.5311 - val_wind_reg_loss: 5.0951 - val_solar_ext_loss: 0.0130 - val_wind_ext_loss: 0.0519
# 55/55 [==============================] - 4s 46ms/step
#
# === Holdout 80/20 ===
#            RMSE       MAE        MAPE        R2       EVS       AUC
# Solar  2.149901  2.044666   32.315917  0.594692  0.610020  0.858377
# Wind   4.715794  4.523226  121.947291 -8.269877 -0.005441  0.621057
#
# FOLD 1
# Epoch 1/20
# 2025-09-02 12:28:04.996500: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 23/23 [==============================] - 13s 212ms/step - loss: 61.0509 - solar_reg_loss: 16.1004 - wind_reg_loss: 44.3699 - solar_ext_loss: 0.3150 - wind_ext_loss: 0.2656
# Epoch 2/20
# 23/23 [==============================] - 3s 115ms/step - loss: 51.6797 - solar_reg_loss: 11.4118 - wind_reg_loss: 39.7078 - solar_ext_loss: 0.3126 - wind_ext_loss: 0.2475
# Epoch 3/20
# 23/23 [==============================] - 3s 109ms/step - loss: 45.9187 - solar_reg_loss: 9.9360 - wind_reg_loss: 35.3605 - solar_ext_loss: 0.3476 - wind_ext_loss: 0.2747
# Epoch 4/20
# 23/23 [==============================] - 2s 107ms/step - loss: 41.8758 - solar_reg_loss: 9.7948 - wind_reg_loss: 31.4130 - solar_ext_loss: 0.3720 - wind_ext_loss: 0.2960
# Epoch 5/20
# 23/23 [==============================] - 3s 126ms/step - loss: 40.2447 - solar_reg_loss: 9.6768 - wind_reg_loss: 29.7881 - solar_ext_loss: 0.4119 - wind_ext_loss: 0.3679
# Epoch 6/20
# 23/23 [==============================] - 3s 139ms/step - loss: 39.5712 - solar_reg_loss: 10.6822 - wind_reg_loss: 28.1381 - solar_ext_loss: 0.3907 - wind_ext_loss: 0.3602
# Epoch 7/20
# 23/23 [==============================] - 3s 121ms/step - loss: 40.1542 - solar_reg_loss: 11.2622 - wind_reg_loss: 28.0936 - solar_ext_loss: 0.3783 - wind_ext_loss: 0.4201
# Epoch 8/20
# 23/23 [==============================] - 3s 114ms/step - loss: 41.2265 - solar_reg_loss: 12.7218 - wind_reg_loss: 27.7953 - solar_ext_loss: 0.3523 - wind_ext_loss: 0.3570
# Epoch 9/20
# 23/23 [==============================] - 3s 114ms/step - loss: 37.7101 - solar_reg_loss: 11.3364 - wind_reg_loss: 25.6138 - solar_ext_loss: 0.3965 - wind_ext_loss: 0.3634
# Epoch 10/20
# 23/23 [==============================] - 3s 109ms/step - loss: 37.6077 - solar_reg_loss: 12.3608 - wind_reg_loss: 24.4728 - solar_ext_loss: 0.3693 - wind_ext_loss: 0.4048
# Epoch 11/20
# 23/23 [==============================] - 3s 111ms/step - loss: 38.0575 - solar_reg_loss: 13.7011 - wind_reg_loss: 23.6979 - solar_ext_loss: 0.3458 - wind_ext_loss: 0.3127
# Epoch 12/20
# 23/23 [==============================] - 3s 109ms/step - loss: 33.3643 - solar_reg_loss: 10.9481 - wind_reg_loss: 21.7494 - solar_ext_loss: 0.2856 - wind_ext_loss: 0.3812
# Epoch 13/20
# 23/23 [==============================] - 2s 106ms/step - loss: 30.9915 - solar_reg_loss: 10.8610 - wind_reg_loss: 19.4824 - solar_ext_loss: 0.2854 - wind_ext_loss: 0.3627
# Epoch 14/20
# 23/23 [==============================] - 3s 111ms/step - loss: 31.6402 - solar_reg_loss: 11.3464 - wind_reg_loss: 19.6287 - solar_ext_loss: 0.2803 - wind_ext_loss: 0.3849
# Epoch 15/20
# 23/23 [==============================] - 3s 109ms/step - loss: 30.3888 - solar_reg_loss: 10.8443 - wind_reg_loss: 18.8739 - solar_ext_loss: 0.2873 - wind_ext_loss: 0.3834
# Epoch 16/20
# 23/23 [==============================] - 3s 111ms/step - loss: 32.7034 - solar_reg_loss: 13.6925 - wind_reg_loss: 18.2687 - solar_ext_loss: 0.2259 - wind_ext_loss: 0.5164
# Epoch 17/20
# 23/23 [==============================] - 3s 109ms/step - loss: 29.5598 - solar_reg_loss: 13.4185 - wind_reg_loss: 15.5141 - solar_ext_loss: 0.2615 - wind_ext_loss: 0.3657
# Epoch 18/20
# 23/23 [==============================] - 2s 105ms/step - loss: 29.0187 - solar_reg_loss: 9.0528 - wind_reg_loss: 19.4383 - solar_ext_loss: 0.2770 - wind_ext_loss: 0.2506
# Epoch 19/20
# 23/23 [==============================] - 3s 110ms/step - loss: 43.6039 - solar_reg_loss: 16.5883 - wind_reg_loss: 25.7832 - solar_ext_loss: 0.6596 - wind_ext_loss: 0.5728
# Epoch 20/20
# 23/23 [==============================] - 3s 110ms/step - loss: 36.3262 - solar_reg_loss: 17.3114 - wind_reg_loss: 18.1361 - solar_ext_loss: 0.3847 - wind_ext_loss: 0.4940
# 46/46 [==============================] - 3s 51ms/step
# Solar fold 1: {'MSE': 17.18682822609355, 'RMSE': 4.145699968171063, 'MAE': 3.608615426328767, 'MAPE': 71.5001998949776, 'R2': -0.23251485315375242, 'EVS': 0.08392783055970143}
# Wind  fold 1: {'MSE': 11.814726423333386, 'RMSE': 3.4372556528913276, 'MAE': 3.234811006436605, 'MAPE': 180.17723886231542, 'R2': -2.91428686304319, 'EVS': 0.01680953969677712}
#
# FOLD 2
# Epoch 1/20
# 2025-09-02 12:29:14.576390: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 46/46 [==============================] - 17s 172ms/step - loss: 58.2378 - solar_reg_loss: 14.3322 - wind_reg_loss: 42.9038 - solar_ext_loss: 0.6811 - wind_ext_loss: 0.3208
# Epoch 2/20
# 46/46 [==============================] - 5s 118ms/step - loss: 45.5807 - solar_reg_loss: 10.3177 - wind_reg_loss: 34.4679 - solar_ext_loss: 0.4450 - wind_ext_loss: 0.3500
# Epoch 3/20
# 46/46 [==============================] - 5s 116ms/step - loss: 41.0506 - solar_reg_loss: 11.2541 - wind_reg_loss: 28.9492 - solar_ext_loss: 0.4779 - wind_ext_loss: 0.3694
# Epoch 4/20
# 46/46 [==============================] - 5s 117ms/step - loss: 36.6821 - solar_reg_loss: 9.6947 - wind_reg_loss: 26.1184 - solar_ext_loss: 0.5065 - wind_ext_loss: 0.3626
# Epoch 5/20
# 46/46 [==============================] - 5s 111ms/step - loss: 33.1702 - solar_reg_loss: 9.7038 - wind_reg_loss: 22.6152 - solar_ext_loss: 0.5347 - wind_ext_loss: 0.3164
# Epoch 6/20
# 46/46 [==============================] - 5s 111ms/step - loss: 31.2360 - solar_reg_loss: 11.4307 - wind_reg_loss: 19.2594 - solar_ext_loss: 0.3435 - wind_ext_loss: 0.2024
# Epoch 7/20
# 46/46 [==============================] - 5s 114ms/step - loss: 15.8134 - solar_reg_loss: 5.0558 - wind_reg_loss: 10.3379 - solar_ext_loss: 0.2784 - wind_ext_loss: 0.1413
# Epoch 8/20
# 46/46 [==============================] - 5s 114ms/step - loss: 21.5710 - solar_reg_loss: 8.8920 - wind_reg_loss: 12.3145 - solar_ext_loss: 0.2404 - wind_ext_loss: 0.1242
# Epoch 9/20
# 46/46 [==============================] - 6s 122ms/step - loss: 29.0754 - solar_reg_loss: 13.8511 - wind_reg_loss: 14.9044 - solar_ext_loss: 0.1925 - wind_ext_loss: 0.1273
# Epoch 10/20
# 46/46 [==============================] - 5s 115ms/step - loss: 22.9456 - solar_reg_loss: 11.8193 - wind_reg_loss: 10.8264 - solar_ext_loss: 0.1739 - wind_ext_loss: 0.1260
# Epoch 11/20
# 46/46 [==============================] - 5s 117ms/step - loss: 19.0776 - solar_reg_loss: 8.7921 - wind_reg_loss: 10.0188 - solar_ext_loss: 0.1595 - wind_ext_loss: 0.1072
# Epoch 12/20
# 46/46 [==============================] - 5s 111ms/step - loss: 13.1704 - solar_reg_loss: 5.9023 - wind_reg_loss: 6.9949 - solar_ext_loss: 0.1618 - wind_ext_loss: 0.1114
# Epoch 13/20
# 46/46 [==============================] - 5s 113ms/step - loss: 14.4431 - solar_reg_loss: 7.6441 - wind_reg_loss: 6.5770 - solar_ext_loss: 0.1263 - wind_ext_loss: 0.0956
# Epoch 14/20
# 46/46 [==============================] - 5s 116ms/step - loss: 11.2035 - solar_reg_loss: 5.4952 - wind_reg_loss: 5.4397 - solar_ext_loss: 0.1462 - wind_ext_loss: 0.1225
# Epoch 15/20
# 46/46 [==============================] - 5s 110ms/step - loss: 9.4897 - solar_reg_loss: 4.2520 - wind_reg_loss: 5.0326 - solar_ext_loss: 0.0971 - wind_ext_loss: 0.1081
# Epoch 16/20
# 46/46 [==============================] - 5s 115ms/step - loss: 6.5523 - solar_reg_loss: 3.0891 - wind_reg_loss: 3.2672 - solar_ext_loss: 0.1041 - wind_ext_loss: 0.0919
# Epoch 17/20
# 46/46 [==============================] - 5s 117ms/step - loss: 5.8918 - solar_reg_loss: 2.8043 - wind_reg_loss: 2.9033 - solar_ext_loss: 0.0868 - wind_ext_loss: 0.0974
# Epoch 18/20
# 46/46 [==============================] - 5s 117ms/step - loss: 5.6104 - solar_reg_loss: 2.5817 - wind_reg_loss: 2.8765 - solar_ext_loss: 0.0712 - wind_ext_loss: 0.0811
# Epoch 19/20
# 46/46 [==============================] - 5s 115ms/step - loss: 4.5804 - solar_reg_loss: 1.8101 - wind_reg_loss: 2.6137 - solar_ext_loss: 0.0738 - wind_ext_loss: 0.0828
# Epoch 20/20
# 46/46 [==============================] - 5s 116ms/step - loss: 4.1935 - solar_reg_loss: 1.7326 - wind_reg_loss: 2.3012 - solar_ext_loss: 0.0775 - wind_ext_loss: 0.0822
# 46/46 [==============================] - 4s 58ms/step
# Solar fold 2: {'MSE': 1.687293460037563, 'RMSE': 1.2989586059754032, 'MAE': 0.9223538958256406, 'MAPE': 14.064814284579679, 'R2': 0.8627009559876531, 'EVS': 0.8892721936535035}
# Wind  fold 2: {'MSE': 4.332456517806232, 'RMSE': 2.081455384534156, 'MAE': 1.873383102724139, 'MAPE': 81.34855176424843, 'R2': -0.6506155700224772, 'EVS': 0.10553352993628651}
#
# FOLD 3
# Epoch 1/20
# 2025-09-02 12:31:19.932126: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 69/69 [==============================] - 22s 175ms/step - loss: 60.6456 - solar_reg_loss: 19.1583 - wind_reg_loss: 40.6779 - solar_ext_loss: 0.3857 - wind_ext_loss: 0.4237
# Epoch 2/20
# 69/69 [==============================] - 8s 115ms/step - loss: 43.2695 - solar_reg_loss: 13.0494 - wind_reg_loss: 29.2925 - solar_ext_loss: 0.4511 - wind_ext_loss: 0.4766
# Epoch 3/20
# 69/69 [==============================] - 8s 112ms/step - loss: 34.5869 - solar_reg_loss: 11.4684 - wind_reg_loss: 22.2076 - solar_ext_loss: 0.4237 - wind_ext_loss: 0.4872
# Epoch 4/20
# 69/69 [==============================] - 8s 112ms/step - loss: 28.6177 - solar_reg_loss: 10.1148 - wind_reg_loss: 17.7968 - solar_ext_loss: 0.3457 - wind_ext_loss: 0.3604
# Epoch 5/20
# 69/69 [==============================] - 8s 111ms/step - loss: 20.0636 - solar_reg_loss: 7.6283 - wind_reg_loss: 11.9624 - solar_ext_loss: 0.2055 - wind_ext_loss: 0.2674
# Epoch 6/20
# 69/69 [==============================] - 8s 113ms/step - loss: 12.1410 - solar_reg_loss: 5.1271 - wind_reg_loss: 6.6729 - solar_ext_loss: 0.1411 - wind_ext_loss: 0.1999
# Epoch 7/20
# 69/69 [==============================] - 8s 114ms/step - loss: 10.1056 - solar_reg_loss: 4.5633 - wind_reg_loss: 5.2271 - solar_ext_loss: 0.1124 - wind_ext_loss: 0.2029
# Epoch 8/20
# 69/69 [==============================] - 8s 114ms/step - loss: 4.0812 - solar_reg_loss: 1.5162 - wind_reg_loss: 2.4157 - solar_ext_loss: 0.0626 - wind_ext_loss: 0.0868
# Epoch 9/20
# 69/69 [==============================] - 8s 113ms/step - loss: 3.1759 - solar_reg_loss: 1.2327 - wind_reg_loss: 1.8158 - solar_ext_loss: 0.0539 - wind_ext_loss: 0.0735
# Epoch 10/20
# 69/69 [==============================] - 8s 117ms/step - loss: 3.2321 - solar_reg_loss: 1.3476 - wind_reg_loss: 1.7491 - solar_ext_loss: 0.0601 - wind_ext_loss: 0.0752
# Epoch 11/20
# 69/69 [==============================] - 8s 114ms/step - loss: 2.7004 - solar_reg_loss: 1.1586 - wind_reg_loss: 1.4191 - solar_ext_loss: 0.0600 - wind_ext_loss: 0.0627
# Epoch 12/20
# 69/69 [==============================] - 8s 115ms/step - loss: 2.6907 - solar_reg_loss: 1.1916 - wind_reg_loss: 1.3868 - solar_ext_loss: 0.0511 - wind_ext_loss: 0.0611
# Epoch 13/20
# 69/69 [==============================] - 8s 122ms/step - loss: 2.4875 - solar_reg_loss: 1.1139 - wind_reg_loss: 1.2570 - solar_ext_loss: 0.0528 - wind_ext_loss: 0.0639
# Epoch 14/20
# 69/69 [==============================] - 8s 114ms/step - loss: 2.9654 - solar_reg_loss: 1.2674 - wind_reg_loss: 1.5751 - solar_ext_loss: 0.0573 - wind_ext_loss: 0.0655
# Epoch 15/20
# 69/69 [==============================] - 8s 111ms/step - loss: 2.4204 - solar_reg_loss: 1.1372 - wind_reg_loss: 1.1673 - solar_ext_loss: 0.0538 - wind_ext_loss: 0.0620
# Epoch 16/20
# 69/69 [==============================] - 8s 116ms/step - loss: 2.3102 - solar_reg_loss: 1.0704 - wind_reg_loss: 1.1317 - solar_ext_loss: 0.0486 - wind_ext_loss: 0.0595
# Epoch 17/20
# 69/69 [==============================] - 8s 113ms/step - loss: 2.6058 - solar_reg_loss: 1.1843 - wind_reg_loss: 1.3041 - solar_ext_loss: 0.0534 - wind_ext_loss: 0.0640
# Epoch 18/20
# 69/69 [==============================] - 8s 109ms/step - loss: 4.5453 - solar_reg_loss: 1.9135 - wind_reg_loss: 2.4844 - solar_ext_loss: 0.0688 - wind_ext_loss: 0.0785
# Epoch 19/20
# 69/69 [==============================] - 7s 108ms/step - loss: 6.7798 - solar_reg_loss: 2.9714 - wind_reg_loss: 3.6459 - solar_ext_loss: 0.0826 - wind_ext_loss: 0.0799
# Epoch 20/20
# 69/69 [==============================] - 7s 108ms/step - loss: 5.0948 - solar_reg_loss: 2.0348 - wind_reg_loss: 2.9171 - solar_ext_loss: 0.0653 - wind_ext_loss: 0.0776
# 46/46 [==============================] - 4s 55ms/step
# Solar fold 3: {'MSE': 167.88649723579402, 'RMSE': 12.957102192843662, 'MAE': 12.906900374809277, 'MAPE': 254.7736811045811, 'R2': -12.952949026229163, 'EVS': 0.8920890739705555}
# Wind  fold 3: {'MSE': 4.119963612932588, 'RMSE': 2.0297693496879363, 'MAE': 1.8447287321811043, 'MAPE': 480.3036469197862, 'R2': -0.15177439418332006, 'EVS': 0.24858613217854497}
#
# FOLD 4
# Epoch 1/20
# 2025-09-02 12:34:18.119133: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 92/92 [==============================] - 25s 153ms/step - loss: 54.5040 - solar_reg_loss: 16.3882 - wind_reg_loss: 37.3298 - solar_ext_loss: 0.4617 - wind_ext_loss: 0.3242
# Epoch 2/20
# 92/92 [==============================] - 10s 108ms/step - loss: 39.6490 - solar_reg_loss: 12.5039 - wind_reg_loss: 26.3393 - solar_ext_loss: 0.4619 - wind_ext_loss: 0.3440
# Epoch 3/20
# 92/92 [==============================] - 10s 107ms/step - loss: 32.4048 - solar_reg_loss: 11.8533 - wind_reg_loss: 19.9588 - solar_ext_loss: 0.3424 - wind_ext_loss: 0.2503
# Epoch 4/20
# 92/92 [==============================] - 10s 109ms/step - loss: 52.3839 - solar_reg_loss: 26.0438 - wind_reg_loss: 25.6882 - solar_ext_loss: 0.3650 - wind_ext_loss: 0.2869
# Epoch 5/20
# 92/92 [==============================] - 10s 108ms/step - loss: 56.7234 - solar_reg_loss: 28.7837 - wind_reg_loss: 27.3046 - solar_ext_loss: 0.3272 - wind_ext_loss: 0.3079
# Epoch 6/20
# 92/92 [==============================] - 10s 108ms/step - loss: 20.8517 - solar_reg_loss: 12.5797 - wind_reg_loss: 8.0372 - solar_ext_loss: 0.0871 - wind_ext_loss: 0.1477
# Epoch 7/20
# 92/92 [==============================] - 10s 108ms/step - loss: 37.6288 - solar_reg_loss: 23.0311 - wind_reg_loss: 14.2110 - solar_ext_loss: 0.1940 - wind_ext_loss: 0.1927
# Epoch 8/20
# 92/92 [==============================] - 10s 107ms/step - loss: 19.4665 - solar_reg_loss: 12.9977 - wind_reg_loss: 6.2519 - solar_ext_loss: 0.1131 - wind_ext_loss: 0.1037
# Epoch 9/20
# 92/92 [==============================] - 10s 107ms/step - loss: 16.2693 - solar_reg_loss: 11.4862 - wind_reg_loss: 4.5839 - solar_ext_loss: 0.1040 - wind_ext_loss: 0.0951
# Epoch 10/20
# 92/92 [==============================] - 10s 111ms/step - loss: 16.7859 - solar_reg_loss: 12.6335 - wind_reg_loss: 3.9444 - solar_ext_loss: 0.1115 - wind_ext_loss: 0.0965
# Epoch 11/20
# 92/92 [==============================] - 10s 109ms/step - loss: 6.8245 - solar_reg_loss: 3.7916 - wind_reg_loss: 2.8774 - solar_ext_loss: 0.0805 - wind_ext_loss: 0.0750
# Epoch 12/20
# 92/92 [==============================] - 10s 109ms/step - loss: 9.5968 - solar_reg_loss: 6.0570 - wind_reg_loss: 3.3604 - solar_ext_loss: 0.0945 - wind_ext_loss: 0.0849
# Epoch 13/20
# 92/92 [==============================] - 10s 107ms/step - loss: 9.3820 - solar_reg_loss: 6.2429 - wind_reg_loss: 2.9621 - solar_ext_loss: 0.0947 - wind_ext_loss: 0.0823
# Epoch 14/20
# 92/92 [==============================] - 10s 108ms/step - loss: 7.4130 - solar_reg_loss: 4.6186 - wind_reg_loss: 2.6159 - solar_ext_loss: 0.0937 - wind_ext_loss: 0.0849
# Epoch 15/20
# 92/92 [==============================] - 10s 107ms/step - loss: 5.4272 - solar_reg_loss: 2.7918 - wind_reg_loss: 2.4881 - solar_ext_loss: 0.0729 - wind_ext_loss: 0.0744
# Epoch 16/20
# 92/92 [==============================] - 10s 108ms/step - loss: 5.2775 - solar_reg_loss: 2.6148 - wind_reg_loss: 2.4919 - solar_ext_loss: 0.0925 - wind_ext_loss: 0.0783
# Epoch 17/20
# 92/92 [==============================] - 10s 108ms/step - loss: 4.7625 - solar_reg_loss: 2.1703 - wind_reg_loss: 2.4301 - solar_ext_loss: 0.0839 - wind_ext_loss: 0.0782
# Epoch 18/20
# 92/92 [==============================] - 10s 109ms/step - loss: 4.4234 - solar_reg_loss: 1.8472 - wind_reg_loss: 2.4254 - solar_ext_loss: 0.0655 - wind_ext_loss: 0.0852
# Epoch 19/20
# 92/92 [==============================] - 10s 109ms/step - loss: 5.5172 - solar_reg_loss: 2.1622 - wind_reg_loss: 3.1868 - solar_ext_loss: 0.0769 - wind_ext_loss: 0.0913
# Epoch 20/20
# 92/92 [==============================] - 10s 108ms/step - loss: 8.5072 - solar_reg_loss: 3.4059 - wind_reg_loss: 4.8888 - solar_ext_loss: 0.1165 - wind_ext_loss: 0.0960
# 46/46 [==============================] - 4s 58ms/step
# Solar fold 4: {'MSE': 4.514918724503366, 'RMSE': 2.124833811031669, 'MAE': 1.9893107533557206, 'MAPE': 31.90471214372322, 'R2': 0.6747427775205236, 'EVS': 0.676655471751574}
# Wind  fold 4: {'MSE': 3.0425333675014206, 'RMSE': 1.7442859190801892, 'MAE': 1.1904333835212122, 'MAPE': 201.12367372120383, 'R2': -0.0693453068357408, 'EVS': -0.04758735933796787}
#
# FOLD 5
# Epoch 1/20
# 2025-09-02 12:37:59.355439: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node Adam/AssignAddVariableOp.
# 114/114 [==============================] - 28s 148ms/step - loss: 53.3846 - solar_reg_loss: 17.0167 - wind_reg_loss: 35.8415 - solar_ext_loss: 0.2440 - wind_ext_loss: 0.2824
# Epoch 2/20
# 114/114 [==============================] - 13s 112ms/step - loss: 34.8413 - solar_reg_loss: 11.7733 - wind_reg_loss: 22.6450 - solar_ext_loss: 0.1908 - wind_ext_loss: 0.2323
# Epoch 3/20
# 114/114 [==============================] - 12s 106ms/step - loss: 22.4670 - solar_reg_loss: 9.3123 - wind_reg_loss: 12.8611 - solar_ext_loss: 0.1501 - wind_ext_loss: 0.1436
# Epoch 4/20
# 114/114 [==============================] - 12s 104ms/step - loss: 39.0779 - solar_reg_loss: 24.4357 - wind_reg_loss: 14.0684 - solar_ext_loss: 0.2803 - wind_ext_loss: 0.2935
# Epoch 5/20
# 114/114 [==============================] - 12s 106ms/step - loss: 14.9887 - solar_reg_loss: 9.4366 - wind_reg_loss: 5.3638 - solar_ext_loss: 0.0927 - wind_ext_loss: 0.0956
# Epoch 6/20
# 114/114 [==============================] - 12s 106ms/step - loss: 10.3414 - solar_reg_loss: 6.0999 - wind_reg_loss: 4.0621 - solar_ext_loss: 0.0956 - wind_ext_loss: 0.0837
# Epoch 7/20
# 114/114 [==============================] - 12s 105ms/step - loss: 13.8451 - solar_reg_loss: 9.6959 - wind_reg_loss: 3.9895 - solar_ext_loss: 0.0835 - wind_ext_loss: 0.0762
# Epoch 8/20
# 114/114 [==============================] - 12s 104ms/step - loss: 7.4953 - solar_reg_loss: 4.4036 - wind_reg_loss: 2.9499 - solar_ext_loss: 0.0733 - wind_ext_loss: 0.0685
# Epoch 9/20
# 114/114 [==============================] - 12s 104ms/step - loss: 6.3308 - solar_reg_loss: 3.5961 - wind_reg_loss: 2.6064 - solar_ext_loss: 0.0601 - wind_ext_loss: 0.0683
# Epoch 10/20
# 114/114 [==============================] - 12s 103ms/step - loss: 4.4937 - solar_reg_loss: 1.9764 - wind_reg_loss: 2.3963 - solar_ext_loss: 0.0534 - wind_ext_loss: 0.0677
# Epoch 11/20
# 114/114 [==============================] - 12s 102ms/step - loss: 4.3484 - solar_reg_loss: 1.9462 - wind_reg_loss: 2.2822 - solar_ext_loss: 0.0548 - wind_ext_loss: 0.0652
# Epoch 12/20
# 114/114 [==============================] - 12s 103ms/step - loss: 4.0262 - solar_reg_loss: 1.6576 - wind_reg_loss: 2.2582 - solar_ext_loss: 0.0496 - wind_ext_loss: 0.0608
# Epoch 13/20
# 114/114 [==============================] - 12s 103ms/step - loss: 4.4677 - solar_reg_loss: 1.9252 - wind_reg_loss: 2.4139 - solar_ext_loss: 0.0631 - wind_ext_loss: 0.0655
# Epoch 14/20
# 114/114 [==============================] - 12s 102ms/step - loss: 13.7735 - solar_reg_loss: 8.8952 - wind_reg_loss: 4.6919 - solar_ext_loss: 0.1081 - wind_ext_loss: 0.0784
# Epoch 15/20
# 114/114 [==============================] - 12s 102ms/step - loss: 14.4976 - solar_reg_loss: 8.2089 - wind_reg_loss: 6.1107 - solar_ext_loss: 0.0993 - wind_ext_loss: 0.0787
# Epoch 16/20
# 114/114 [==============================] - 12s 102ms/step - loss: 16.9797 - solar_reg_loss: 8.8697 - wind_reg_loss: 7.9435 - solar_ext_loss: 0.0848 - wind_ext_loss: 0.0818
# Epoch 17/20
# 114/114 [==============================] - 12s 102ms/step - loss: 20.2003 - solar_reg_loss: 8.0446 - wind_reg_loss: 11.9543 - solar_ext_loss: 0.1060 - wind_ext_loss: 0.0953
# Epoch 18/20
# 114/114 [==============================] - 12s 102ms/step - loss: 12.4693 - solar_reg_loss: 5.4415 - wind_reg_loss: 6.8308 - solar_ext_loss: 0.1008 - wind_ext_loss: 0.0963
# Epoch 19/20
# 114/114 [==============================] - 12s 103ms/step - loss: 11.4929 - solar_reg_loss: 3.9636 - wind_reg_loss: 7.3496 - solar_ext_loss: 0.0962 - wind_ext_loss: 0.0835
# Epoch 20/20
# 114/114 [==============================] - 12s 102ms/step - loss: 11.1567 - solar_reg_loss: 3.4016 - wind_reg_loss: 7.5558 - solar_ext_loss: 0.1035 - wind_ext_loss: 0.0959
# 46/46 [==============================] - 4s 56ms/step
# Solar fold 5: {'MSE': 63.96678458675802, 'RMSE': 7.997923767250974, 'MAE': 7.915762819864198, 'MAPE': 124.15908611567663, 'R2': -4.699893154753834, 'EVS': 0.8818550529738665}
# Wind  fold 5: {'MSE': 123.64979152575809, 'RMSE': 11.119792782500854, 'MAE': 10.99771862629951, 'MAPE': 595.3843027076605, 'R2': -48.95246838510115, 'EVS': -0.09074581700199791}
#
# === CV Summary Solar ===
#            mean        std   CI90_low   CI90_high
# MSE   51.048464  69.940180 -15.631865  117.728794
# RMSE   5.704904   4.809176   1.119879   10.289928
# MAE    5.468589   4.938377   0.760385   10.176792
# MAPE  99.280499  96.656645   7.128936  191.432062
# R2    -3.269583   5.866656  -8.862799    2.323634
# EVS    0.684760   0.348110   0.352875    1.016645
#
# === CV Summary Wind ===
#             mean         std   CI90_low   CI90_high
# MSE    29.391894   52.807298 -20.954101   79.737890
# RMSE    4.082512    3.988263   0.280139    7.884885
# MAE     3.828215    4.076377  -0.058165    7.714595
# MAPE  307.667483  218.752039  99.111287  516.223678
# R2    -10.547698   21.500109 -31.045705    9.950309
# EVS     0.046519    0.134995  -0.082183    0.175222
#
# === CV Summary AUCs ===
# AUC_s    0.698739
# AUC_w    0.459912
# dtype: float64
